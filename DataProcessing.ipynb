# %%
# !rm -rf Autonomous-Demand-Forecasting-Decision-Intelligence-Platform
# !git clone https://github.com/AbhishekSrivastava-07/Autonomous-Demand-Forecasting-Decision-Intelligence-Platform.git/
# Out:
# Cloning into 'Autonomous-Demand-Forecasting-Decision-Intelligence-Platform'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 59 (delta 20), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (59/59), 22.38 KiB | 22.38 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
# !rm -rf Autonomous-Demand-Forecasting-Decision-Intelligence-Platform
# %run /content/Autonomous-Demand-Forecasting-Decision-Intelligence-Platform/Config.ipynb
# Out:
# fatal: destination path 'Autonomous-Demand-Forecasting-Decision-Intelligence-Platform' already exists and is not an empty directory.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %run /content/Autonomous-Demand-Forecasting-Decision-Intelligence-Platform/Imports.ipynb

# %%
# import pandas as pd
print(Data_path)
# Out:
# /content/drive/MyDrive/Colab Notebooks/ADF_DIP/ADFDIP_source_data.csv

# %%
RT = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ADF_DIP/ADFDIP_source_data.csv")
print(Data_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1830/596513174.py in <cell line: 0>()
# ----> 1 RT = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ADF_DIP/ADFDIP_source_data.csv")
#       2 print(Data_path)
#
# ...
