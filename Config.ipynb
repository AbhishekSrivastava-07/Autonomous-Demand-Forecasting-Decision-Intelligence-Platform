# %%
# !git clone https://github.com/AbhishekSrivastava-07/Autonomous-Demand-Forecasting-Decision-Intelligence-Platform.git/

# %%
# %run /content/Autonomous-Demand-Forecasting-Decision-Intelligence-Platform/Imports.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Data_path = "/content/drive/MyDrive/Colab Notebooks/ADF_DIP/ADFDIP_source_data.csv"

# %%
from google.colab import userdata
import os

os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

#OpenAI
openai = OpenAI()
MODEL = 'gpt-5-nano'

# Gemini
genai.configure(api_key = userdata.get('Gemini_API'))
# Suppose I want to use any of the model to generate content
Gemini_model = genai.GenerativeModel("models/gemini-2.5-flash-lite")

GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=userdata.get('Gemini_API'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1732/4018177746.py in <cell line: 0>()
#       5
#       6 #OpenAI
# ----> 7 openai = OpenAI()
#       8 MODEL = 'gpt-5-nano'
#       9
#
# NameError: name 'OpenAI' is not defined
